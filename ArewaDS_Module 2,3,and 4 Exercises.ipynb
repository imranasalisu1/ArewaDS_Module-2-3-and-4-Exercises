# %%
# Module 2,3,and 4 Exercises

# %%
# Write a python comment saying 'Day 2: 30 Days of python programming'
# Day 2: 30 Days of python programming

# %%
first_name = 'imrana'  # Declare a first name variable and assign a value to it
last_name = 'salisu'   # Declare a last name variable and assign a value to it
full_name = first_name + last_name # Declare a full name variable and assign a value to it
print(full_name)
# Out:
# imranasalisu

# %%
country = 'Nigeria' # Declare a country variable and assign a value to it
city = 'Katsina'  # Declare a city variable and assign a value to it
age = 30  # Declare an age variable and assign a value to it
year = 2025 # Declare a year variable and assign a value to it
print(country)
print(city)
print(age)
print(year)
# Out:
# Nigeria
# Katsina
# 30
# 2025

# %%
is_married = 'yes' # Declare a variable is_married and assign a value to it
is_true = 'no' # Declare a variable is_true and assign a value to it
is_light_on = 'yes' # Declare a variable is_light_on and assign a value to it
a,b,c = 2,3,4 # Declare multiple variable on one line

# %%
# Exercises: Level 2
# Check the data type of all your variables using type() built-in function
type(first_name)
type(last_name)
type(full_name)
type(country)
type(city)
type(age)
type(year)
# Using the len() built-in function, find the length of your first name
len(first_name)
# Compare the length of your first name and your last name
len(last_name)
# Declare 5 as num_one and 4 as num_two
num_one = 5
num_two = 4
# Add num_one and num_two and assign the value to a variable total
total_variable = (num_one + num_two)

# %%
variable_diff = (num_one - num_two) # Subtract num_two from num_one and assign the value to a variable diff
variable_product = (num_two * num_one) # Multiply num_two and num_one and assign the value to a variable product
variable_division = (num_one / num_two) # Divide num_one by num_two and assign the value to a variable division
variable_reminder = (num_two % num_one) # Use modulus division to find num_two divided by num_one and assign the value to a variable remainder
variable_exp = ( num_one**num_two) # Calculate num_one to the power of num_two and assign the value to a variable exp
variable_floor_division = (num_one // num_two) # Find floor division of num_one by num_two and assign the value to a variable floor_division

# %%
# The radius of a circle is 30 meters.
# Calculate the area of a circle and assign the value to a variable name of area_of_circle
# Calculate the circumference of a circle and assign the value to a variable name of circum_of_circle
# Take radius as user input and calculate the area.
# Use the built-in input function to get first name, last name, country and age from a user and store the value to their corresponding variable names
# Run help('keywords') in Python shell or in your file to check for the Python reserved words or keywords

# %%
import math  # Importing math module for pi
# Given radius
radius = 30
# Calculate area of the circle
area_of_circle = math.pi * radius**2
print("Area of the circle:", area_of_circle)
# Calculate circumference of the circle
circum_of_circle = 2 * math.pi * radius
print("Circumference of the circle:", circum_of_circle)
# Take radius as user input and calculate the area
radius_input = float(input("Enter the radius of the circle: "))
area_user_input = math.pi * radius_input**2
print("Area of the circle with user input radius:", area_user_input)
# Input user details
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
country = input("Enter your country: ")
age = input("Enter your age: ")
# Print user details
print(f"First Name: {first_name}, Last Name: {last_name}, Country: {country}, Age: {age}")
# Check Python reserved keywords
help('keywords')
# Out:
# Area of the circle: 2827.4333882308138
# Circumference of the circle: 188.49555921538757
